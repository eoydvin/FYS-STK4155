# %%
import requests
import pandas as pd

# Insert your own client ID here
client_id = '6e7d29f6-8f77-4317-b9a6-846a7052852c'

# %%
# Define endpoint and parameters
endpoint = 'https://frost.met.no/observations/v0.jsonld'
parameters = {
    'sources': 'GR1',
    'elements': 'over_time(equivalent_reflectivity_factor PT1M)',
    'referencetime': 'latest',
}
# Issue an HTTP GET request
r = requests.get(endpoint, parameters, auth=(client_id,''))
# Extract JSON data
json = r.json()

# %%
# Check if the request worked, print out any errors
if r.status_code == 200:
    data = json['data']
    print('Data retrieved from frost.met.no!')
else:
    print('Error! Returned status code %s' % r.status_code)
    print('Message: %s' % json['error']['message'])
    print('Reason: %s' % json['error']['reason'])
# Out:
# Error! Returned status code 412
# Message: 412
# Reason: No time series found for this combination of parameters, check /observations/availableTimeSeries for more information.

# %%
# This will return a Dataframe with all of the observations in a table format
df = pd.DataFrame()
for i in range(len(data)):
    row = pd.DataFrame(data[i]['observations'])
    row['referenceTime'] = data[i]['referenceTime']
    row['sourceId'] = data[i]['sourceId']
    df = df.append(row)

df = df.reset_index()

# %%
df
# Out:
#     index                      elementId  value  unit  \
# 0       0      mean(air_temperature P1D)    3.2  degC
# 1       1      mean(air_temperature P1D)    3.0  degC
# 2       2  sum(precipitation_amount P1D)   13.5    mm
# 3       3  sum(precipitation_amount P1D)   29.0    mm
# 4       4           mean(wind_speed P1D)    1.7   m/s
# 5       0      mean(air_temperature P1D)    3.0  degC
# 6       1      mean(air_temperature P1D)    3.2  degC
# 7       2  sum(precipitation_amount P1D)    3.3    mm
# 8       3  sum(precipitation_amount P1D)    9.0    mm
# 9       4           mean(wind_speed P1D)    2.9   m/s
# 10      0      mean(air_temperature P1D)    2.1  degC
# 11      1      mean(air_temperature P1D)   -0.9  degC
# 12      2  sum(precipitation_amount P1D)    0.0    mm
# 13      3  sum(precipitation_amount P1D)    0.0    mm
# 14      4           mean(wind_speed P1D)    1.3   m/s
# 15      0      mean(air_temperature P1D)    6.1  degC
# 16      1      mean(air_temperature P1D)    3.4  degC
# 17      2  sum(precipitation_amount P1D)    0.0    mm
# 18      3  sum(precipitation_amount P1D)    0.0    mm
# 19      4           mean(wind_speed P1D)    3.9   m/s
#
#                                                 level timeOffset  \
# 0   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 1   {'levelType': 'height_above_ground', 'unit': '...       PT6H
# 2                                                 NaN      PT18H
# 3                                                 NaN       PT6H
# 4   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 5   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 6   {'levelType': 'height_above_ground', 'unit': '...       PT6H
# 7                                                 NaN      PT18H
# 8                                                 NaN       PT6H
# 9   {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 10  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 11  {'levelType': 'height_above_ground', 'unit': '...       PT6H
# 12                                                NaN      PT18H
# 13                                                NaN       PT6H
# 14  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 15  {'levelType': 'height_above_ground', 'unit': '...       PT0H
# 16  {'levelType': 'height_above_ground', 'unit': '...       PT6H
# 17                                                NaN      PT18H
# 18                                                NaN       PT6H
# 19  {'levelType': 'height_above_ground', 'unit': '...       PT0H
#
#    timeResolution  timeSeriesId performanceCategory exposureCategory  \
# 0             P1D             0                   C                2
# 1             P1D             0                   C                2
# 2             P1D             0                   C                2
# 3             P1D             0                   C                2
# 4             P1D             0                   C                2
# 5             P1D             0                   C                2
# 6             P1D             0                   C                2
# 7             P1D             0                   C                2
# 8             P1D             0                   C                2
# 9             P1D             0                   C                2
# 10            P1D             0                   C                2
# 11            P1D             0                   C                2
# 12            P1D             0                   C                2
# 13            P1D             0                   C                2
# 14            P1D             0                   C                2
# 15            P1D             0                   C                2
# 16            P1D             0                   C                2
# 17            P1D             0                   C                2
# 18            P1D             0                   C                2
# 19            P1D             0                   C                2
#
#     qualityCode             referenceTime   sourceId
# 0             2  2010-04-01T00:00:00.000Z  SN18700:0
# 1             2  2010-04-01T00:00:00.000Z  SN18700:0
# 2             2  2010-04-01T00:00:00.000Z  SN18700:0
# 3             2  2010-04-01T00:00:00.000Z  SN18700:0
# 4             2  2010-04-01T00:00:00.000Z  SN18700:0
# 5             2  2010-04-02T00:00:00.000Z  SN18700:0
# 6             2  2010-04-02T00:00:00.000Z  SN18700:0
# 7             2  2010-04-02T00:00:00.000Z  SN18700:0
# 8             2  2010-04-02T00:00:00.000Z  SN18700:0
# 9             2  2010-04-02T00:00:00.000Z  SN18700:0
# 10            2  2010-04-01T00:00:00.000Z  SN90450:0
# 11            2  2010-04-01T00:00:00.000Z  SN90450:0
# 12            2  2010-04-01T00:00:00.000Z  SN90450:0
# 13            2  2010-04-01T00:00:00.000Z  SN90450:0
# 14            2  2010-04-01T00:00:00.000Z  SN90450:0
# 15            2  2010-04-02T00:00:00.000Z  SN90450:0
# 16            2  2010-04-02T00:00:00.000Z  SN90450:0
# 17            2  2010-04-02T00:00:00.000Z  SN90450:0
# 18            2  2010-04-02T00:00:00.000Z  SN90450:0
# 19            2  2010-04-02T00:00:00.000Z  SN90450:0
